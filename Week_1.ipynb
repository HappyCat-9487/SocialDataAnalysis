# %%
import pandas as pd
data = pd.read_csv("Data_1.csv")
data.head()
# Out:
#              PdId  IncidntNum  Incident Code        Category  \
# 0   3114751606302    31147516           6302   LARCENY/THEFT
# 1   5069701104134    50697011           4134         ASSAULT
# 2   6074729204104    60747292           4104         ASSAULT
# 3   7103536315201    71035363          15201         ASSAULT
# 4  11082415274000   110824152          74000  MISSING PERSON
#
#                       Descript  DayOfWeek        Date   Time PdDistrict  \
# 0  PETTY THEFT FROM A BUILDING     Sunday  09/28/2003  10:00   SOUTHERN
# 1                      BATTERY  Wednesday  06/22/2005  12:20   NORTHERN
# 2                      ASSAULT   Saturday  07/15/2006  00:55    CENTRAL
# 3                     STALKING    Tuesday  09/25/2007  00:01    TARAVAL
# 4                MISSING ADULT   Saturday  09/24/2011  11:00    TARAVAL
#
#   Resolution  ... Fix It Zones as of 2017-11-06  2 2  DELETE - HSOC Zones 2 2  \
# 0       NONE  ...                                NaN                      NaN
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Jennifer\\Social Data Analysis'

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints', 'Data_1.csv', 'Week_1.ipynb']

# %%
for i in data:
    h++
    
print(h)
# Out:
#   File "<ipython-input-4-cf6c6770a67f>", line 2
#     h++
#        ^
# SyntaxError: invalid syntax

# %%
h=0
for i in data:
    h = h+1
    
print(h)
# Out:
# 35

# %%
total = len(data.readlines())
print(total)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ae435320dd43> in <module>
# ----> 1 total = len(data.readlines())
#       2 print(total)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'readlines'

# %%
total = sum(1 for line in data)
print(total)
# Out:
# 35

# %%
print(len(data))
# Out:
# 2129525

# %%
print(len(data.rows))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-b72d19680ee6> in <module>
# ----> 1 print(len(data.rows))
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
print(len(data.row))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-0b4755190814> in <module>
# ----> 1 print(len(data.row))
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
print(len(list(data))
# Out:
#   File "<ipython-input-11-b591b22e29fb>", line 1
#     print(len(list(data))
#                          ^
# SyntaxError: unexpected EOF while parsing

# %%
print(len(list(data)))
# Out:
# 35

# %%
row_count = sum(1 for row in data)
print(row_count)
# Out:
# 35

# %%
print(len(data))
# Out:
# 2129525

# %%
print data.value_counts()
print data['Category'].value_counts()
# Out:
#   File "<ipython-input-15-6c1c26b415b1>", line 1
#     print data.value_counts()
#              ^
# SyntaxError: invalid syntax

# %%
print(data.value_counts())
print(data['Category'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-b312c92335a9> in <module>
# ----> 1 print(data.value_counts())
#       2 print(data['Category'].value_counts())
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
import panda as pd
data = pd.read_csv("Data_1.csv")
print(data.value_counts())
print(data['Category'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-cf13e0f58d4b> in <module>
# ----> 1 import panda as pd
#       2 data = pd.read_csv("Data_1.csv")
#       3 print(data.value_counts())
#       4 print(data['Category'].value_counts())
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd
data = pd.read_csv("Data_1.csv")
print(data.value_counts())
print(data['Category'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-04e77d7ff5d2> in <module>
#       1 import pandas as pd
#       2 data = pd.read_csv("Data_1.csv")
# ----> 3 print(data.value_counts())
#       4 print(data['Category'].value_counts())
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
data.shape
# Out:
# (2129525, 35)

# %%
data[].groupby(by = 'Category').sum()
# Out:
#   File "<ipython-input-20-6b34d9552829>", line 1
#     data[].groupby(by = 'Category').sum()
#          ^
# SyntaxError: invalid syntax

# %%
data.groupby(by = 'Category').sum()
# Out:
#                                             PdId      IncidntNum  \
# Category
# ARSON                          40502574673273864    405025745724
# ASSAULT                      1720200488476612864  17202004871960
# BAD CHECKS                      7760539098945060     77605390906
# BRIBERY                         8906697266144929     89066972454
# BURGLARY                      920797806428046848   9207978059673
# DISORDERLY CONDUCT             94492074755842656    944920745456
# DRIVING UNDER THE INFLUENCE    60572909718663352    605729093510
# DRUG/NARCOTIC                1056885071237289216  10568850692917
# DRUNKENNESS                    95932110520701344    959321103344
# EMBEZZLEMENT                   29866806906105920    298668068774
# EXTORTION                       7511770755206560     75117707362
# FORGERY/COUNTERFEITING        190888921999240640   1908889217885
# FRAUD                         426682596683175808   4266825961960
# ...

# %%
h = data.groupby(by = 'Category').sum()
print(h)
# Out:
#                                             PdId      IncidntNum  \
# Category
# ARSON                          40502574673273864    405025745724
# ASSAULT                      1720200488476612864  17202004871960
# BAD CHECKS                      7760539098945060     77605390906
# BRIBERY                         8906697266144929     89066972454
# BURGLARY                      920797806428046848   9207978059673
# DISORDERLY CONDUCT             94492074755842656    944920745456
# DRIVING UNDER THE INFLUENCE    60572909718663352    605729093510
# DRUG/NARCOTIC                1056885071237289216  10568850692917
# DRUNKENNESS                    95932110520701344    959321103344
# EMBEZZLEMENT                   29866806906105920    298668068774
# EXTORTION                       7511770755206560     75117707362
# FORGERY/COUNTERFEITING        190888921999240640   1908889217885
# FRAUD                         426682596683175808   4266825961960
# ...

# %%
len(data.groupby(by = 'Category').sum())
# Out:
# 37

# %%
data.groupby(by = 'Category')[].sum()
# Out:
#   File "<ipython-input-24-d16e0621cee6>", line 1
#     data.groupby(by = 'Category')[].sum()
#                                   ^
# SyntaxError: invalid syntax

# %%
data['Category'].sum()

# %%
data.groupby(by = 'Category')['Category'].sum()
print(len(data.groupby(by = 'Category').sum()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9abfe0f1bf33> in <module>
# ----> 1 data.groupby(by = 'Category')['Category'].sum()
#       2 print(len(data.groupby(by = 'Category').sum()))
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
data = pd.read_csv("Data_1.csv")
data.groupby(by = 'Category')['Category'].sum()
print(len(data.groupby(by = 'Category').sum()))

# %%
import pandas as pd
data = pd.read_csv("Data_1.csv")
data.head()
# Out:
#              PdId  IncidntNum  Incident Code        Category  \
# 0   3114751606302    31147516           6302   LARCENY/THEFT
# 1   5069701104134    50697011           4134         ASSAULT
# 2   6074729204104    60747292           4104         ASSAULT
# 3   7103536315201    71035363          15201         ASSAULT
# 4  11082415274000   110824152          74000  MISSING PERSON
#
#                       Descript  DayOfWeek        Date   Time PdDistrict  \
# 0  PETTY THEFT FROM A BUILDING     Sunday  09/28/2003  10:00   SOUTHERN
# 1                      BATTERY  Wednesday  06/22/2005  12:20   NORTHERN
# 2                      ASSAULT   Saturday  07/15/2006  00:55    CENTRAL
# 3                     STALKING    Tuesday  09/25/2007  00:01    TARAVAL
# 4                MISSING ADULT   Saturday  09/24/2011  11:00    TARAVAL
#
#   Resolution  ... Fix It Zones as of 2017-11-06  2 2  DELETE - HSOC Zones 2 2  \
# 0       NONE  ...                                NaN                      NaN
# ...

# %%
data.groupby(by = 'Category')['Category'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1f61e2ea0823> in <module>
# ----> 1 data.groupby(by = 'Category')['Category'].sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in f(self, **kwargs)
#    1375
#    1376                 # apply a non-cython aggregation
# -> 1377                 result = self.aggregate(lambda x: npfunc(x, axis=self.axis))
#    1378
#    1379                 # coerce the resulting columns if we can
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     861
#     862             try:
# --> 863                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     864             except Exception:
#     865                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#
# ...

# %%
data['Category'].sum()

# %%
data[data['Category']].groupby(by = 'Category').sum()

# %%
data.groupby(['Category']).count()

# %%
print(data.groupby(['Category']).count())

# %%
print(data['Category'])

# %%
print(data[3][0:5])

# %%
data.groupby(by = 'Category').sum()
